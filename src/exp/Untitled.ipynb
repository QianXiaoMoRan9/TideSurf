# %%
import pandas as pd 
import pyarrow as pa 
import pyarrow.parquet as pq

# %%
table2 = pq.read_table('/home/steven/Desktop/Fast500/astock_parquet/2020-12-21/000001.parquet')

# %%
pandas_table = table2.to_pandas()

# %%
pandas_table.head(100)
# Out:
#      ask1  ask1_volume   ask2  ask2_volume   ask3  ask3_volume   ask4  \
# 0   18.42       162000   0.00         1929   0.00            0   0.00
# 1   18.42       162400   0.00         2029   0.00            0   0.00
# 2   18.42       162500   0.00         1929   0.00            0   0.00
# 3   18.40       166700   0.00        44029   0.00            0   0.00
# 4   18.40       167300   0.00        48029   0.00            0   0.00
# ..    ...          ...    ...          ...    ...          ...    ...
# 95  18.06         4900  18.07         4100  18.08        60300  18.09
# 96  18.08          700  18.09          800  18.10       292000  18.11
# 97  18.08         4300  18.09         1100  18.10       292000  18.11
# 98  18.09         1000  18.10       267100  18.11         1500  18.12
# 99  18.09         5500  18.10       267100  18.11         1500  18.12
#
#     ask4_volume   ask5  ask5_volume  ...  high    low    now  open   sell  \
# ...

# %%
table2.schema
# Out:
# ask1: double
#   -- field metadata --
#   PARQUET:field_id: '1'
# ask1_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '2'
# ask2: double
#   -- field metadata --
#   PARQUET:field_id: '3'
# ask2_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '4'
# ask3: double
#   -- field metadata --
#   PARQUET:field_id: '5'
# ask3_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '6'
# ask4: double
#   -- field metadata --
#   PARQUET:field_id: '7'
# ask4_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '8'
# ask5: double
#   -- field metadata --
#   PARQUET:field_id: '9'
# ask5_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '10'
# bid1: double
#   -- field metadata --
#   PARQUET:field_id: '11'
# bid1_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '12'
# bid2: double
#   -- field metadata --
#   PARQUET:field_id: '13'
# bid2_volume: int64
#   -- field metadata --
#   PARQUET:field_id: '14'
# bid3: double
# ...
